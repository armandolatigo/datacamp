# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: six in /Users/armandolatigo/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.623, 6.972]
plt.plot(year, pop)
plt.show()

# %%
plt.scatter(year, pop)
plt.show()
